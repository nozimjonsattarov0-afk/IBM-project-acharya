# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../data/processed/cleaned_data.csv')
print(df.head())
# Out:
#   Customer_ID                       Full_Name  Age  Gender Purchased_Product  \
# 0      C_1001      Torayev Asadbek Ilhomovich   24       1            Laptop
# 1      C_1002  Nishonov Mirzabek Mrodbek ogli   31       1        Smartphone
# 2      C_1003  BOLTAYEV JASURBEK SHUXRAT OGLI   22       1           Monitor
# 3      C_1004   Eshbekov Sardor Namozboy ogli   28       1        Smartwatch
# 4      C_1005             Rahmonova Mehrigiyo   21       0            Tablet
#
#    Purchase_Amount
# 0             1200
# 1              850
# 2              300
# 3              150
# 4              450

# %%
# Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=10, kde=True, color='blue')
plt.title('Customer Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Product Sales
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Purchased_Product', palette='magma')
plt.title('Sales Count by Product')
plt.xlabel('Product')
plt.ylabel('Quantity Sold')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Product Sales
# ----> 2 plt.figure(figsize=(12, 6))
#       3 sns.countplot(data=df, x='Purchased_Product', palette='magma')
#       4 plt.title('Sales Count by Product')
#
# NameError: name 'plt' is not defined

# %%
# Spending by Gender
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Purchase_Amount', data=df)
plt.title('Purchase Amount by Gender (1=Male, 0=Female)')
plt.ylabel('Total Spend ($)')
plt.show()
